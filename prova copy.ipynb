# %%
import pandas as pd
from helpermodules import memory_handling as mh
import numpy as np
from datetime import timedelta, datetime
import time

# %%
# downloading the pickle file 
file = "fedspeeches_preprocessed.pkl"
helper = mh.PickleHelper.pickle_load(file)
df = helper.obj

# %%
from twelvedata import TDClient
td = TDClient(apikey="ce7c5d1412ff42d1a2ca90e47bd3105f")

# %%
# choosing only the assigned speakers for the analysis
speaker_list_riccardo = [ 'Vice Chair Janet L. Yellen', 'Governor Sarah Bloom Raskin', 'Governor Jeremy C. Stein', 'Governor Jerome H. Powell', 'Chairman  Ben S. Bernanke', 'Governor Lael Brainard', 'Chair Janet L. Yellen', 'Vice Chairman Stanley Fischer', 'Vice Chairman for Supervision Randal K. Quarles', 'Chairman Jerome H. Powell', 'Vice Chairman Richard H. Clarida', 'Chair Jerome H. Powell', 'Vice Chair Richard H. Clarida', 'Vice Chair for Supervision Randal K. Quarles']
speaker_list = ['Governor Michelle W. Bowman', 'Vice Chair for Supervision and Chair of the Financial Stability Board Randal K. Quarles', 'Vice Chairman for Supervision and Chair of the Financial Stability Board Randal K. Quarles', 'Governor Christopher J. Waller', 'Governor Randal K. Quarles', 'Vice Chair for Supervision Michael S. Barr', 'Governor Lisa D. Cook', 'Vice Chair Lael Brainard', 'Governor Philip N. Jefferson', 'Chair Pro Tempore Jerome H. Powell', 'Vice Chair Philip N. Jefferson', 'Governor Adriana D. Kugler']
df = df[df['speaker'].isin(speaker_list)]

# %%
def data_retrieve_minute(df, ticker):
    """
    Retrieve minute-level time series data for a specified ticker using the Twelve Data API.

    Parameters:
    df : pandas.DataFrame
        A dataframe containing at least two columns:
        - 'date': Dates for which data needs to be retrieved.
        - 'timestamp': Timestamps corresponding to the data entries.
    ticker : str
        The symbol of the financial instrument to retrieve data for.

    Returns:
    dffinal : pandas.DataFrame
        A concatenated DataFrame containing minute-level data for the specified ticker
        across all the unique dates in the provided dataframe `df`. The DataFrame will have:
        - 'date' as the index
        - A 'timestamp' column representing the minute-level time series.
    """
    
    timelist = df.date.unique().tolist()
    count = 0
    dffinal = pd.DataFrame()

    for date in timelist:
        print(f"Processing date: {date}")
        start = df[df['date'] == date].timestamp.min() - pd.Timedelta(minutes=15)
        end = df[df['date'] == date].timestamp.max() + pd.Timedelta(minutes=15)

        if count % 8 == 0 and count > 0:
            time.sleep(60)

        try:
            etf = td.time_series(
                symbol=ticker,
                interval="1min",
                start_date=start,
                end_date=end,
                outputsize=5000    
            ).as_pandas()
            
            # If the API call returns data, concatenate it to the final DataFrame
            if not etf.empty:
                # Add a 'date' column to the ETF DataFrame to use as an index later
                etf['date'] = date
                dffinal = pd.concat([dffinal, etf], ignore_index=False)
            else:
                print(f"No data available for {date}")

        except Exception as e:
            print(f"Error retrieving data for {date}: {e}")

        count += 1
    
    # Set the 'date' as the index and move 'timestamp' into a separate column
    dffinal.reset_index(inplace=True)
    dffinal.rename(columns={'index': 'timestamp'}, inplace=True)
    dffinal.set_index('date', inplace=True)
    
    return dffinal

# %%
def volatility_calculator(df):
    """
    Calculate daily volatility for the 'open' column in the dataframe.

    Parameters:
    df : pandas.DataFrame
        A dataframe containing at least 'date' and 'open' columns.

    Returns:
    pandas.Series
        A series with dates as the index and the standard deviation
        of 'open' values (volatility) as the values.
    """

    volatility_series = df.groupby('date')['open'].std()
    return volatility_series

# %%
def clean_df(df):
    """
    Clean the dataframe by sorting and filtering based on date and weekdays.

    Parameters:
    df : pandas.DataFrame
        A dataframe containing at least 'date' and 'timestamp' columns.

    Returns:
    pandas.DataFrame
        A dataframe sorted by 'date' and 'timestamp', filtered to include only
        rows with dates >= '2020-12-01' and weekdays (Monday to Friday).
    """
        
    df_ordered = df.sort_values(by=['date', 'timestamp'], ascending = [True, True])
    df_final = df_ordered[df_ordered.date >= "2020-12-01"]
    df_final = df_final[df_final['date'].dt.weekday<5]
    return df_final

# %%
def get_best_values(volatility, df, number):
    """
    Filter the dataframe for the top dates with the highest volatility.

    Parameters:
    volatility : pandas.Series
        A series with dates as the index and volatility as the values.
    df : pandas.DataFrame
        The dataframe to filter, containing a 'date' column.
    number : int
        The number of top volatility dates to select.

    Returns:
    pandas.DataFrame
        A filtered dataframe containing rows with dates matching the top 
        `number` volatility values.
    """
    
    # Sort the volatility in descending order
    volatility = volatility.sort_values(ascending=False)

    # Get the top `number` dates with the highest volatility
    top_dates = volatility.head(number).index.tolist()

    # Filter the dataframe for rows where 'date' is in the top_dates
    filtered_df = df[df['date'].isin(top_dates)]

    return filtered_df

# %%
df=clean_df(df)

# %%
#estimated time 30 mins
df_price=data_retrieve_minute(df,'SPY')
'''picklehelper = mh.PickleHelper(df_price)
picklehelper.pickle_dump("fabio2020onwardpricemovements")'''

# %%
volatility=volatility_calculator(df_price)
newdf=get_best_values(volatility,df,5)

# %%
newdf
# Out:
#             date                      speaker  \
# 20081 2021-02-16  Governor Michelle W. Bowman
# 20082 2021-02-16  Governor Michelle W. Bowman
# 20083 2021-02-16  Governor Michelle W. Bowman
# 20084 2021-02-16  Governor Michelle W. Bowman
# 20085 2021-02-16  Governor Michelle W. Bowman
# 20086 2021-02-16  Governor Michelle W. Bowman
# 20087 2021-02-16  Governor Michelle W. Bowman
# 20088 2021-02-16  Governor Michelle W. Bowman
# 20089 2021-02-16  Governor Michelle W. Bowman
# 20090 2021-02-16  Governor Michelle W. Bowman
# 20091 2021-02-16  Governor Michelle W. Bowman
# 20092 2021-02-16  Governor Michelle W. Bowman
# 20093 2021-02-16  Governor Michelle W. Bowman
# 20094 2021-02-16  Governor Michelle W. Bowman
# 20095 2021-02-16  Governor Michelle W. Bowman
# 20096 2021-02-16  Governor Michelle W. Bowman
# 20054 2021-02-22  Governor Michelle W. Bowman
# 20055 2021-02-22  Governor Michelle W. Bowman
# 20056 2021-02-22  Governor Michelle W. Bowman
# 20057 2021-02-22  Governor Michelle W. Bowman
# 20058 2021-02-22  Governor Michelle W. Bowman
# 20059 2021-02-22  Governor Michelle W. Bowman
# 20060 2021-02-22  Governor Michelle W. Bowman
#
#                                                    title  \
# 20081  My Perspective on Bank Regulation and Supervision
# 20082  My Perspective on Bank Regulation and Supervision
# 20083  My Perspective on Bank Regulation and Supervision
# 20084  My Perspective on Bank Regulation and Supervision
# 20085  My Perspective on Bank Regulation and Supervision
# 20086  My Perspective on Bank Regulation and Supervision
# 20087  My Perspective on Bank Regulation and Supervision
# 20088  My Perspective on Bank Regulation and Supervision
# 20089  My Perspective on Bank Regulation and Supervision
# 20090  My Perspective on Bank Regulation and Supervision
# 20091  My Perspective on Bank Regulation and Supervision
# 20092  My Perspective on Bank Regulation and Supervision
# 20093  My Perspective on Bank Regulation and Supervision
# 20094  My Perspective on Bank Regulation and Supervision
# 20095  My Perspective on Bank Regulation and Supervision
# 20096  My Perspective on Bank Regulation and Supervision
# 20054     Economic Inclusion in Lower-Income Communities
# 20055     Economic Inclusion in Lower-Income Communities
# 20056     Economic Inclusion in Lower-Income Communities
# 20057     Economic Inclusion in Lower-Income Communities
# 20058     Economic Inclusion in Lower-Income Communities
# 20059     Economic Inclusion in Lower-Income Communities
# 20060     Economic Inclusion in Lower-Income Communities
#
#                                          link  \
# 20081  /newsevents/speech/bowman20210216a.htm
# 20082  /newsevents/speech/bowman20210216a.htm
# 20083  /newsevents/speech/bowman20210216a.htm
# 20084  /newsevents/speech/bowman20210216a.htm
# 20085  /newsevents/speech/bowman20210216a.htm
# 20086  /newsevents/speech/bowman20210216a.htm
# 20087  /newsevents/speech/bowman20210216a.htm
# 20088  /newsevents/speech/bowman20210216a.htm
# 20089  /newsevents/speech/bowman20210216a.htm
# 20090  /newsevents/speech/bowman20210216a.htm
# 20091  /newsevents/speech/bowman20210216a.htm
# 20092  /newsevents/speech/bowman20210216a.htm
# 20093  /newsevents/speech/bowman20210216a.htm
# 20094  /newsevents/speech/bowman20210216a.htm
# 20095  /newsevents/speech/bowman20210216a.htm
# 20096  /newsevents/speech/bowman20210216a.htm
# 20054  /newsevents/speech/bowman20210222a.htm
# 20055  /newsevents/speech/bowman20210222a.htm
# 20056  /newsevents/speech/bowman20210222a.htm
# 20057  /newsevents/speech/bowman20210222a.htm
# 20058  /newsevents/speech/bowman20210222a.htm
# 20059  /newsevents/speech/bowman20210222a.htm
# 20060  /newsevents/speech/bowman20210222a.htm
#
#                                                     text  \
# 20081  Good morning. I want to thank the American Ban...
# 20082  Good morning. I want to thank the American Ban...
# 20083  Good morning. I want to thank the American Ban...
# 20084  Good morning. I want to thank the American Ban...
# 20085  Good morning. I want to thank the American Ban...
# 20086  Good morning. I want to thank the American Ban...
# 20087  Good morning. I want to thank the American Ban...
# 20088  Good morning. I want to thank the American Ban...
# 20089  Good morning. I want to thank the American Ban...
# 20090  Good morning. I want to thank the American Ban...
# 20091  Good morning. I want to thank the American Ban...
# 20092  Good morning. I want to thank the American Ban...
# 20093  Good morning. I want to thank the American Ban...
# 20094  Good morning. I want to thank the American Ban...
# 20095  Good morning. I want to thank the American Ban...
# 20096  Good morning. I want to thank the American Ban...
# 20054  Thank you, President Kaplan, our Advance Toget...
# 20055  Thank you, President Kaplan, our Advance Toget...
# 20056  Thank you, President Kaplan, our Advance Toget...
# 20057  Thank you, President Kaplan, our Advance Toget...
# 20058  Thank you, President Kaplan, our Advance Toget...
# 20059  Thank you, President Kaplan, our Advance Toget...
# 20060  Thank you, President Kaplan, our Advance Toget...
#
#                       timestamp  \
# 20081 2021-02-16 10:00:00-05:00
# 20082 2021-02-16 10:01:00-05:00
# 20083 2021-02-16 10:02:00-05:00
# 20084 2021-02-16 10:03:00-05:00
# 20085 2021-02-16 10:04:00-05:00
# 20086 2021-02-16 10:05:00-05:00
# 20087 2021-02-16 10:06:00-05:00
# 20088 2021-02-16 10:07:00-05:00
# 20089 2021-02-16 10:08:00-05:00
# 20090 2021-02-16 10:09:00-05:00
# 20091 2021-02-16 10:10:00-05:00
# 20092 2021-02-16 10:11:00-05:00
# 20093 2021-02-16 10:12:00-05:00
# 20094 2021-02-16 10:13:00-05:00
# 20095 2021-02-16 10:14:00-05:00
# 20096 2021-02-16 10:15:00-05:00
# 20054 2021-02-22 10:00:00-05:00
# 20055 2021-02-22 10:01:00-05:00
# 20056 2021-02-22 10:02:00-05:00
# 20057 2021-02-22 10:03:00-05:00
# 20058 2021-02-22 10:04:00-05:00
# 20059 2021-02-22 10:05:00-05:00
# 20060 2021-02-22 10:06:00-05:00
#
#                                           text_by_minute
# 20081  Good morning. I want to thank the American Ban...
# 20082  continue to make, a huge difference in the liv...
# 20083  improve oversight of community banks over the ...
# 20084  striking the right balance means that at some ...
# 20085  should be effective, but also efficient, and t...
# 20086  availability of services in a community, as we...
# 20087  respect for the reasonable application of them...
# 20088  will not be necessary because we encourage com...
# 20089  aimed at curbing proprietary trading by large ...
# 20090  streamline the examination process for lower r...
# 20091  to provide financial services and best meet th...
# 20092  and outcomes for similarly situated institutio...
# 20093  third-party risk management, a guide on sound ...
# 20094  framework and its impact on their business str...
# 20095  who were struggling with circumstances through...
# 20096             I look forward to your questions, Rob.
# 20054  Thank you, President Kaplan, our Advance Toget...
# 20055  families. Likewise, reducing the disparities i...
# 20056  insurance benefits and other financial assista...
# 20057  these complex problems alone.The Importance of...
# 20058  and approach from community to community, the ...
# 20059  opportunity. The Big Country Manufacturing All...
# 20060                             Governors, September).
